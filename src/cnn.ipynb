# %% [markdown]
# ## Tugas Besar II IF3270 Pembelajaran Mesin - CNN
#
# ### Anggota Kelompok:
# 1. Suthasoma Mahardhika Munthe (13522098)
# 2. Marvin Scifo Y. Hutahaean (13522110)
# 3. Berto Richardo Togatorop (13522118)

# %%
# Import Dataset
import tensorflow as tf
from keras import datasets
import numpy as np
from sklearn.model_selection import train_test_split
from utilfunc import UtilisationFunctions

# Load CIFAR-10 Dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

y_train = y_train.flatten()
y_test = y_test.flatten()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

x_train_scratch = np.transpose(x_train, (0,3,1,2))
x_test_scratch = np.transpose(x_test, (0,3,1,2))

# %% [markdown]
# ## Import Models

# %%
from customnn import Conv2D, Pooling, ReLU, FullyConnected, Dropout, RNN, LSTM, TextVectorization, Embedded, Flatten
from keras import models
from keras import layers

# %%
class CNNKeras():
    def __init__(self, num_classes=10):
        self.model = [
            # 2 Layers
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(128, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 3 Layers
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 4 Layers
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(256, (3, 3), padding='same', name='conv4'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(512, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 2x2 Kernel
            models.Sequential([
                layers.Conv2D(32, (2, 2), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (2, 2), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (2, 2), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 3x3 Kernel
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 4x4 Kernel
            models.Sequential([
                layers.Conv2D(32, (4, 4), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (4, 4), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (4, 4), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 16, 32, 64 Filters
            models.Sequential([
                layers.Conv2D(16, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(32, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(128, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 32, 64, 128 Filters
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),
            
            # 64, 128, 256 Filters
            models.Sequential([
                layers.Conv2D(64, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(256, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(512, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # Max Pooling
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # Average Pooling
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.AveragePooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.AveragePooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.AveragePooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dropout(0.5),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),
        ]

# %%
from keras import layers, models, Input

# Define the input
inputs = Input(shape=(32, 32, 3), name='input')

def print_flattened(x):
    tf.print("Flattened output shape:", tf.shape(x))
    tf.print("Flattened sample:", x)
    return x

def print_tensor(x):
    tf.print("conv1 output sample:", x)
    return x


x = layers.Conv2D(32, (3, 3), padding="same", name='conv1')(inputs)
x = layers.ReLU(name='relu1')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='max1')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2')(x)
x = layers.ReLU(name='relu2')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='max2')(x)

x = layers.Conv2D(128, (3, 3), padding='same', name='conv3')(x)
x = layers.ReLU(name='relu3')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), strides=1, name='max3')(x)

x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu', name='fc1')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation='softmax', name='fc2')(x)

model = models.Model(inputs=inputs, outputs=outputs, name='custom_cnn')

model.summary()
# Out:
# Model: "custom_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu1 (ReLU)                    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max1 (MaxPooling2D)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu2 (ReLU)                    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max2 (MaxPooling2D)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu3 (ReLU)                    │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max3 (MaxPooling2D)             │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,701,706 (6.49 MB)
#  Trainable params: 1,701,706 (6.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class CNNFromScratch():
    def __init__(self, num_classes=10):
        self.conv1 = Conv2D(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = ReLU()
        self.pool1 = Pooling(kernel_size=2, stride=2, method='max')
        self.conv2 = Conv2D(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = ReLU()
        self.pool2 = Pooling(kernel_size=2, stride=2, method='max')
        self.conv3 = Conv2D(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu3 = ReLU()
        self.pool3 = Pooling(kernel_size=2, stride=1, method='max')
        self.flat = Flatten()
        self.drop1 = Dropout(dropout_rate=0.5)
        self.full1 = FullyConnected(input_size=128*7*7, output_size=256, activation="reLU", weight_init="xavier", 
                                    lower=-0.05, upper=0.05, mean=0, variance=1, seed=None, use_rmsnorm=False)
        self.drop2 = Dropout(dropout_rate=0.5)
        self.full2 = FullyConnected(input_size=256, output_size=num_classes, activation="softmax", weight_init="xavier",
                                    lower=-0.05, upper=0.05, mean=0, variance=1, seed=None, use_rmsnorm=False)
        
    def forward(self, x):
        # print(x.shape)
        x = self.pool1.forward(self.relu1.forward(x))
        # print(x.shape)
        x = self.conv2.forward(x)
        # print(x.shape)
        x = self.pool2.forward(self.relu2.forward(x))
        # print(x.shape)
        x = self.conv3.forward(x)
        # print(x.shape)
        x = self.pool3.forward(self.relu3.forward(x))
        # print(x.shape)
        x = self.flat.forward(x)
        # print(x.shape)
        x = self.drop1.forward(self.full1.forward(x))
        # print(x.shape)
        x = self.full2.forward(x)
        # print(x.shape)
        return x
    
    def backward(self, grad_output, learning_rate=0.005):
        grad = self.full2.backward(grad_output=grad_output)
        grad = self.drop1.backward(grad)
        grad = self.full1.backward(grad)
        grad = self.flat.backward(grad)
        grad = self.pool3.backward(grad)
        grad = self.relu3.backward(grad)
        grad = self.conv3.backward(grad, learning_rate)
        grad = self.pool2.backward(grad)
        grad = self.relu2.backward(grad)
        grad = self.conv2.backward(grad, learning_rate)
        grad = self.pool1.backward(grad)
        grad = self.relu1.backward(grad)
        grad = self.conv1.backward(grad, learning_rate)

# %%
model_names = [
    "2 Layers",
    "3 Layers",
    "4 Layers",
    "2x2 Kernel",
    "3x3 Kernel",
    "4x4 Kernel",
    "16, 32, 64 Filters",
    "32, 64, 128 Filters",
    "64, 128, 256 Filters",
    "Max Pooling",
    "Average Pooling"
]

# %% [markdown]
# ## CNN Keras

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=['accuracy']
)
model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2
)
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.3307 - loss: 1.7995 - val_accuracy: 0.5414 - val_loss: 1.2629
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.5510 - loss: 1.2554 - val_accuracy: 0.6479 - val_loss: 0.9899
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6280 - loss: 1.0550 - val_accuracy: 0.6866 - val_loss: 0.8922
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6720 - loss: 0.9305 - val_accuracy: 0.6940 - val_loss: 0.8750
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6986 - loss: 0.8530 - val_accuracy: 0.7306 - val_loss: 0.7739
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.7303 - loss: 0.7689 - val_accuracy: 0.7407 - val_loss: 0.7467
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.7416 - loss: 0.7250 - val_accuracy: 0.7466 - val_loss: 0.7311
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.7643 - loss: 0.6803 - val_accuracy: 0.7570 - val_loss: 0.6976
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.7720 - loss: 0.6442 - val_accuracy: 0.7488 - val_loss: 0.7313
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.7887 - loss: 0.5985 - val_accuracy: 0.7568 - val_loss: 0.6997
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7504 - loss: 0.7145

# %%
def transfer_conv_weights(custom_conv, keras_layer):
    weights, biases = keras_layer.get_weights()
    weights = np.transpose(weights, (3, 2, 0, 1))
    custom_conv.kernel = weights
    custom_conv.bias = biases
def transfer_full_weights(custom_full, keras_layer):
    weights, biases = keras_layer.get_weights()
    # print("Dense weights shape (keras):", weights.shape)
    # if your custom weights expect (output_dim, input_dim), transpose
    custom_full.weights = weights
    custom_full.biases = biases

# %%
cnn_from_scratch = CNNFromScratch()

transfer_conv_weights(cnn_from_scratch.conv1, model.get_layer('conv1'))
transfer_conv_weights(cnn_from_scratch.conv2, model.get_layer('conv2'))
transfer_conv_weights(cnn_from_scratch.conv3, model.get_layer('conv3'))

transfer_full_weights(cnn_from_scratch.full1, model.get_layer('fc1'))
transfer_full_weights(cnn_from_scratch.full2, model.get_layer('fc2'))

# %%
import numpy as np
from collections import Counter
from sklearn.metrics import f1_score

batch_size = 100
correct = 0
pred_counts = Counter()

# Assuming x_test and y_test are already defined and preprocessed appropriately
batch = x_test[:batch_size].transpose(0, 3, 1, 2)  # Shape for custom CNN
print(batch.shape)
batch_keras = x_test[:batch_size]                  # Shape for Keras model
# print(batch_keras.shape)

# Lists to store true and predicted labels
true_labels = []
predictions_scratch = []
predictions_keras = []

# np.set_printoptions(threshold=np.inf, linewidth=np.inf, suppress=True)

first_conv_layer = model.get_layer(name='conv1')
conv_output_model = models.Model(inputs=model.input, outputs=first_conv_layer.output)

start_layer = model.get_layer('relu1')
end_layer = model.get_layer('fc2')
submodel = models.Model(inputs=start_layer.input, outputs=end_layer.output)

for i in range(batch_size):
    input_keras = batch_keras[i]
    input_custom = input_keras.transpose(2,0,1)
    out_custom = cnn_from_scratch.conv1.forward(input_custom)
    out_keras = model.predict(input_keras[np.newaxis, ...])

    out_custom = out_custom.transpose(1,2,0)

    not_final_custom = cnn_from_scratch.pool1.forward(cnn_from_scratch.relu1.forward(out_custom).transpose(2,0,1)).transpose(1,2,0)
    # not_final_keras = submodel.predict(out_keras)

    conv_2_custom = cnn_from_scratch.conv2.forward(not_final_custom.transpose(2,0,1)).transpose(1,2,0)
    relu_2_custom = cnn_from_scratch.relu2.forward(conv_2_custom)
    pool_2_custom = cnn_from_scratch.pool2.forward(relu_2_custom.transpose(2,0,1)).transpose(1,2,0)

    conv_3_custom = cnn_from_scratch.conv3.forward(pool_2_custom.transpose(2,0,1)).transpose(1,2,0)
    relu_3_custom = cnn_from_scratch.relu3.forward(conv_3_custom)
    pool_3_custom = cnn_from_scratch.pool3.forward(relu_3_custom.transpose(2,0,1)).transpose(1,2,0)

    flat_custom = cnn_from_scratch.flat.forward(pool_3_custom)
    drop1_custom = cnn_from_scratch.drop1.forward(flat_custom)
    full1_custom = cnn_from_scratch.full1.forward(drop1_custom)
    drop2_custom = cnn_from_scratch.drop2.forward(full1_custom)
    full2_custom = cnn_from_scratch.full2.forward(drop2_custom)

    # Prediction and comparison
    pred = int(np.argmax(full2_custom))
    pred_keras = int(np.argmax(out_keras))
    label = int(y_test[i])

    true_labels.append(label)
    predictions_scratch.append(pred)
    predictions_keras.append(pred_keras)

f1_rating = f1_score(predictions_keras, predictions_scratch, average='macro')

print("Macro F1-score:", f1_rating)
# Out:
# (100, 3, 32, 32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Macro F1-score: 0.8347634708286883

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)

n = 0

cnn_models = CNNKeras()

for model in cnn_models.model:
    print(model_names[n])
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=['accuracy']
    )
    history = model.fit(
        x_train, y_train,
        epochs=10,
        batch_size=64,
        validation_split=0.2
    )
    test_loss, test_acc = model.evaluate(x_val, y_val)

    y_pred_probs = model.predict(x_val)
    y_pred = np.argmax(y_pred_probs, axis=1)
    f1 = f1_score(y_val, y_pred, average='macro')

    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"F1 Score: {f1:.4f}")

    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(model_names[n])
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    n += 1
    print()
# Out:
# c:\Users\Marvin Scifo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2 Layers
# Epoch 1/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 15s 45ms/step - accuracy: 0.2632 - loss: 1.9953 - val_accuracy: 0.4693 - val_loss: 1.4863
# Epoch 2/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.4429 - loss: 1.5354 - val_accuracy: 0.5436 - val_loss: 1.2674
# Epoch 3/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.5071 - loss: 1.3775 - val_accuracy: 0.5793 - val_loss: 1.2071
# Epoch 4/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.5449 - loss: 1.2786 - val_accuracy: 0.6123 - val_loss: 1.1338
# Epoch 5/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.5758 - loss: 1.1945 - val_accuracy: 0.5838 - val_loss: 1.1801
# Epoch 6/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.5792 - loss: 1.1692 - val_accuracy: 0.6273 - val_loss: 1.0540
# Epoch 7/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.6091 - loss: 1.0887 - val_accuracy: 0.6398 - val_loss: 1.0246
# Epoch 8/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.6363 - loss: 1.0305 - val_accuracy: 0.6297 - val_loss: 1.0472
# Epoch 9/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.