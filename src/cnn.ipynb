# %% [markdown]
# ## Tugas Besar II IF3270 Pembelajaran Mesin - CNN
#
# ### Anggota Kelompok:
# 1. Suthasoma Mahardhika Munthe (13522098)
# 2. Marvin Scifo Y. Hutahaean (13522110)
# 3. Berto Richardo Togatorop (13522118)

# %%
# Import Dataset
import tensorflow as tf
from keras import datasets
import numpy as np
from sklearn.model_selection import train_test_split
from utilfunc import UtilisationFunctions

# Load CIFAR-10 Dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

y_train = y_train.flatten()
y_test = y_test.flatten()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

x_train_scratch = np.transpose(x_train, (0,3,1,2))
x_test_scratch = np.transpose(x_test, (0,3,1,2))

# %% [markdown]
# ## Import Models

# %%
from customnn import Conv2D, Pooling, ReLU, FullyConnected, Dropout, RNN, LSTM, TextVectorization, Embedded, Flatten
from keras import models
from keras import layers

# %%
class CNNKeras():
    def __init__(self, num_classes=10):
        self.model = [
            # 2 Layers
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(128, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 3 Layers
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 4 Layers
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(256, (3, 3), padding='same', name='conv4'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(512, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 2x2 Kernel
            models.Sequential([
                layers.Conv2D(32, (2, 2), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (2, 2), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (2, 2), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 3x3 Kernel
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 4x4 Kernel
            models.Sequential([
                layers.Conv2D(32, (4, 4), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (4, 4), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (4, 4), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 16, 32, 64 Filters
            models.Sequential([
                layers.Conv2D(16, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(32, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(128, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # 32, 64, 128 Filters
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),
            
            # 64, 128, 256 Filters
            models.Sequential([
                layers.Conv2D(64, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(256, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(512, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # Max Pooling
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.MaxPooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),

            # Average Pooling
            models.Sequential([
                layers.Conv2D(32, (3, 3), padding="same", name='conv1', input_shape=(32, 32, 3)),
                layers.ReLU(),
                layers.AveragePooling2D(pool_size=(2, 2)),

                layers.Conv2D(64, (3, 3), padding='same', name='conv2'),
                layers.ReLU(),
                layers.AveragePooling2D(pool_size=(2, 2)),

                layers.Conv2D(128, (3, 3), padding='same', name='conv3'),
                layers.ReLU(),
                layers.AveragePooling2D(pool_size=(2, 2), strides=1),

                layers.Flatten(),
                layers.Dense(256, activation='relu', name='fc1'),
                layers.Dense(num_classes, activation='softmax', name='fc2')
            ]),
        ]

# %%
from keras import layers, models, Input

# Define the input
inputs = Input(shape=(32, 32, 3), name='input')

def print_flattened(x):
    tf.print("Flattened output shape:", tf.shape(x))
    tf.print("Flattened sample:", x)
    return x

def print_tensor(x):
    tf.print("conv1 output sample:", x)
    return x


x = layers.Conv2D(32, (3, 3), padding="same", name='conv1')(inputs)
x = layers.ReLU(name='relu1')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='max1')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2')(x)
x = layers.ReLU(name='relu2')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='max2')(x)

x = layers.Conv2D(128, (3, 3), padding='same', name='conv3')(x)
x = layers.ReLU(name='relu3')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), strides=1, name='max3')(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu', name='fc1')(x)
outputs = layers.Dense(10, activation='softmax', name='fc2')(x)

model = models.Model(inputs=inputs, outputs=outputs, name='custom_cnn')

model.summary()
# Out:
# Model: "custom_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu1 (ReLU)                    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max1 (MaxPooling2D)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu2 (ReLU)                    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max2 (MaxPooling2D)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu3 (ReLU)                    │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max3 (MaxPooling2D)             │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,701,706 (6.49 MB)
#  Trainable params: 1,701,706 (6.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class CNNFromScratch():
    def __init__(self, num_classes=10):
        self.conv1 = Conv2D(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = ReLU()
        self.pool1 = Pooling(kernel_size=2, stride=2, method='max')
        self.conv2 = Conv2D(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = ReLU()
        self.pool2 = Pooling(kernel_size=2, stride=2, method='max')
        self.conv3 = Conv2D(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu3 = ReLU()
        self.pool3 = Pooling(kernel_size=2, stride=1, method='max')
        self.flat = Flatten()
        self.full1 = FullyConnected(input_size=128*7*7, output_size=256, activation="reLU", weight_init="xavier", 
                                    lower=-0.05, upper=0.05, mean=0, variance=1, seed=None, use_rmsnorm=False)
        self.drop1 = Dropout()
        self.full2 = FullyConnected(input_size=256, output_size=num_classes, activation="softmax", weight_init="xavier",
                                    lower=-0.05, upper=0.05, mean=0, variance=1, seed=None, use_rmsnorm=False)
        
    def forward(self, x):
        # print(x.shape)
        x = self.pool1.forward(self.relu1.forward(x))
        # print(x.shape)
        x = self.conv2.forward(x)
        # print(x.shape)
        x = self.pool2.forward(self.relu2.forward(x))
        # print(x.shape)
        x = self.conv3.forward(x)
        # print(x.shape)
        x = self.pool3.forward(self.relu3.forward(x))
        # print(x.shape)
        x = self.flat.forward(x)
        # print(x.shape)
        x = self.drop1.forward(self.full1.forward(x))
        # print(x.shape)
        x = self.full2.forward(x)
        # print(x.shape)
        return x
    
    def backward(self, grad_output, learning_rate=0.005):
        grad = self.full2.backward(grad_output=grad_output)
        grad = self.drop1.backward(grad)
        grad = self.full1.backward(grad)
        grad = self.flat.backward(grad)
        grad = self.pool3.backward(grad)
        grad = self.relu3.backward(grad)
        grad = self.conv3.backward(grad, learning_rate)
        grad = self.pool2.backward(grad)
        grad = self.relu2.backward(grad)
        grad = self.conv2.backward(grad, learning_rate)
        grad = self.pool1.backward(grad)
        grad = self.relu1.backward(grad)
        grad = self.conv1.backward(grad, learning_rate)

# %%
model_names = [
    "2 Layers",
    "3 Layers",
    "4 Layers",
    "2x2 Kernel",
    "3x3 Kernel",
    "4x4 Kernel",
    "16, 32, 64 Filters",
    "32, 64, 128 Filters",
    "64, 128, 256 Filters",
    "Max Pooling",
    "Average Pooling"
]

# %% [markdown]
# ## CNN Keras

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=['accuracy']
)
model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2
)
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 33ms/step - accuracy: 0.3818 - loss: 1.6833 - val_accuracy: 0.6019 - val_loss: 1.1285
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.6387 - loss: 1.0255 - val_accuracy: 0.6749 - val_loss: 0.9412
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.7109 - loss: 0.8244 - val_accuracy: 0.6837 - val_loss: 0.9065
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.7661 - loss: 0.6734 - val_accuracy: 0.7281 - val_loss: 0.7763
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.8070 - loss: 0.5559 - val_accuracy: 0.7558 - val_loss: 0.7352
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.8396 - loss: 0.4581 - val_accuracy: 0.7435 - val_loss: 0.7767
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.8752 - loss: 0.3658 - val_accuracy: 0.7527 - val_loss: 0.7872
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9020 - loss: 0.2860 - val_accuracy: 0.7390 - val_loss: 0.9088
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9263 - loss: 0.2146 - val_accuracy: 0.7437 - val_loss: 1.0138
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9454 - loss: 0.1568 - val_accuracy: 0.7352 - val_loss: 1.1166
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7357 - loss: 1.1278

# %%
def transfer_conv_weights(custom_conv, keras_layer):
    weights, biases = keras_layer.get_weights()
    weights = np.transpose(weights, (3, 2, 0, 1))
    custom_conv.kernel = weights
    custom_conv.bias = biases
def transfer_full_weights(custom_full, keras_layer):
    weights, biases = keras_layer.get_weights()
    # print("Dense weights shape (keras):", weights.shape)
    # if your custom weights expect (output_dim, input_dim), transpose
    custom_full.weights = weights
    custom_full.biases = biases

# %%
cnn_from_scratch = CNNFromScratch()

transfer_conv_weights(cnn_from_scratch.conv1, model.get_layer('conv1'))
transfer_conv_weights(cnn_from_scratch.conv2, model.get_layer('conv2'))
transfer_conv_weights(cnn_from_scratch.conv3, model.get_layer('conv3'))

transfer_full_weights(cnn_from_scratch.full1, model.get_layer('fc1'))
transfer_full_weights(cnn_from_scratch.full2, model.get_layer('fc2'))

# %%
import numpy as np
from collections import Counter
from sklearn.metrics import f1_score

batch_size = 10
correct = 0
pred_counts = Counter()

# Assuming x_test and y_test are already defined and preprocessed appropriately
batch = x_test[:batch_size].transpose(0, 3, 1, 2)  # Shape for custom CNN
print(batch.shape)
batch_keras = x_test[:batch_size]                  # Shape for Keras model
# print(batch_keras.shape)

# Lists to store true and predicted labels
true_labels = []
predictions_scratch = []
predictions_keras = []

# np.set_printoptions(threshold=np.inf, linewidth=np.inf, suppress=True)

first_conv_layer = model.get_layer(name='conv1')
conv_output_model = models.Model(inputs=model.input, outputs=first_conv_layer.output)

start_layer = model.get_layer('relu1')
end_layer = model.get_layer('fc2')
submodel = models.Model(inputs=start_layer.input, outputs=end_layer.output)

for i in range(batch_size):
    input_keras = batch_keras[i]
    input_custom = input_keras.transpose(2,0,1)
    out_custom = cnn_from_scratch.conv1.forward(input_custom)
    out_keras = model.predict(input_keras[np.newaxis, ...])

    out_custom = out_custom.transpose(1,2,0)

    not_final_custom = cnn_from_scratch.pool1.forward(cnn_from_scratch.relu1.forward(out_custom).transpose(2,0,1)).transpose(1,2,0)
    # not_final_keras = submodel.predict(out_keras)

    conv_2_custom = cnn_from_scratch.conv2.forward(not_final_custom.transpose(2,0,1)).transpose(1,2,0)
    relu_2_custom = cnn_from_scratch.relu2.forward(conv_2_custom)
    pool_2_custom = cnn_from_scratch.pool2.forward(relu_2_custom.transpose(2,0,1)).transpose(1,2,0)

    conv_3_custom = cnn_from_scratch.conv3.forward(pool_2_custom.transpose(2,0,1)).transpose(1,2,0)
    relu_3_custom = cnn_from_scratch.relu3.forward(conv_3_custom)
    pool_3_custom = cnn_from_scratch.pool3.forward(relu_3_custom.transpose(2,0,1)).transpose(1,2,0)

    flat_custom = cnn_from_scratch.flat.forward(pool_3_custom)
    full1_custom = cnn_from_scratch.full1.forward(flat_custom)
    full2_custom = cnn_from_scratch.full2.forward(full1_custom)

    # Prediction and comparison
    pred = int(np.argmax(full2_custom))
    pred_keras = int(np.argmax(out_keras))
    label = int(y_test[i])

    true_labels.append(label)
    predictions_scratch.append(pred)
    predictions_keras.append(pred_keras)

f1_rating = f1_score(predictions_keras, predictions_scratch, average='macro')

print("Macro F1-score:", f1_rating)
# Out:
# (10, 3, 32, 32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Macro F1-score: 1.0

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)

n = 0

cnn_models = CNNKeras()

for model in cnn_models.model:
    print(model_names[n])
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=['accuracy']
    )
    history = model.fit(
        x_train, y_train,
        epochs=10,
        batch_size=64,
        validation_split=0.2
    )
    test_loss, test_acc = model.evaluate(x_val, y_val)

    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(model_names[n])
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    n += 1
    print()
# Out:
# c:\Users\Marvin Scifo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2 Layers
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - accuracy: 0.3651 - loss: 1.7452 - val_accuracy: 0.5723 - val_loss: 1.2232
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.5867 - loss: 1.1697 - val_accuracy: 0.6014 - val_loss: 1.1264
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.6623 - loss: 0.9710 - val_accuracy: 0.6431 - val_loss: 1.0144
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.7077 - loss: 0.8362 - val_accuracy: 0.6592 - val_loss: 0.9827
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.7498 - loss: 0.7111 - val_accuracy: 0.6513 - val_loss: 1.0126
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.7933 - loss: 0.6026 - val_accuracy: 0.6823 - val_loss: 0.9719
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.8330 - loss: 0.4890 - val_accuracy: 0.6495 - val_loss: 1.1041
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8579 - loss: 0.4163 - val_accuracy: 0.6575 - val_loss: 1.1054
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9025 - loss: 0.2937 - val_accuracy: 0.6770 - val_loss: 1.1559
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.9312 - loss: 0.2154 - val_accuracy: 0.6711 - val_loss: 1.2792
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6504 - loss: 1.3639
# 3 Layers
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.3367 - loss: 1.7948 - val_accuracy: 0.5509 - val_loss: 1.2610
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.5802 - loss: 1.1767 - val_accuracy: 0.6170 - val_loss: 1.0816
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.6586 - loss: 0.9663 - val_accuracy: 0.6662 - val_loss: 0.9354
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7166 - loss: 0.8054 - val_accuracy: 0.6856 - val_loss: 0.8934
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.7641 - loss: 0.6718 - val_accuracy: 0.7069 - val_loss: 0.8638
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8003 - loss: 0.5679 - val_accuracy: 0.6859 - val_loss: 0.9070
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8354 - loss: 0.4646 - val_accuracy: 0.7186 - val_loss: 0.8681
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8797 - loss: 0.3453 - val_accuracy: 0.6963 - val_loss: 0.9550
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9086 - loss: 0.2711 - val_accuracy: 0.7130 - val_loss: 0.9681
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9329 - loss: 0.2063 - val_accuracy: 0.7141 - val_loss: 1.0848
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7020 - loss: 1.1614
# 4 Layers
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.3099 - loss: 1.8539 - val_accuracy: 0.5148 - val_loss: 1.3743
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.5538 - loss: 1.2309 - val_accuracy: 0.6145 - val_loss: 1.0832
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.6591 - loss: 0.9496 - val_accuracy: 0.6266 - val_loss: 1.0352
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.7167 - loss: 0.8052 - val_accuracy: 0.6544 - val_loss: 0.9994
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.7641 - loss: 0.6637 - val_accuracy: 0.7019 - val_loss: 0.8803
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8136 - loss: 0.5373 - val_accuracy: 0.7142 - val_loss: 0.8661
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8587 - loss: 0.4063 - val_accuracy: 0.7041 - val_loss: 0.9529
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8920 - loss: 0.3098 - val_accuracy: 0.7141 - val_loss: 0.9732
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.9266 - loss: 0.2163 - val_accuracy: 0.7020 - val_loss: 1.1643
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.9417 - loss: 0.1699 - val_accuracy: 0.7017 - val_loss: 1.2773
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6963 - loss: 1.2775
# 2x2 Kernel
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.3451 - loss: 1.7950 - val_accuracy: 0.5348 - val_loss: 1.2936
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.5676 - loss: 1.2212 - val_accuracy: 0.6009 - val_loss: 1.1190
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.6435 - loss: 1.0090 - val_accuracy: 0.6486 - val_loss: 0.9967
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.6882 - loss: 0.8756 - val_accuracy: 0.6888 - val_loss: 0.9173
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.7316 - loss: 0.7628 - val_accuracy: 0.6839 - val_loss: 0.9122
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.7617 - loss: 0.6884 - val_accuracy: 0.6822 - val_loss: 0.9358
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.7877 - loss: 0.6008 - val_accuracy: 0.7123 - val_loss: 0.8729
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.8285 - loss: 0.4988 - val_accuracy: 0.6913 - val_loss: 0.9807
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8537 - loss: 0.4206 - val_accuracy: 0.7022 - val_loss: 0.9419
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.8891 - loss: 0.3312 - val_accuracy: 0.7092 - val_loss: 0.9770
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7088 - loss: 0.9705
# 3x3 Kernel
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.3451 - loss: 1.7807 - val_accuracy: 0.5619 - val_loss: 1.2376
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.5726 - loss: 1.1986 - val_accuracy: 0.6284 - val_loss: 1.0376
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.6578 - loss: 0.9751 - val_accuracy: 0.6656 - val_loss: 0.9777
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.7232 - loss: 0.7936 - val_accuracy: 0.6709 - val_loss: 0.9752
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.7532 - loss: 0.7022 - val_accuracy: 0.6922 - val_loss: 0.9456
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.7924 - loss: 0.5897 - val_accuracy: 0.7148 - val_loss: 0.8679
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8392 - loss: 0.4668 - val_accuracy: 0.7189 - val_loss: 0.8772
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8711 - loss: 0.3692 - val_accuracy: 0.7158 - val_loss: 0.9087
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9013 - loss: 0.2868 - val_accuracy: 0.7209 - val_loss: 1.0073
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.9280 - loss: 0.2146 - val_accuracy: 0.7192 - val_loss: 1.0620
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7074 - loss: 1.0798
# 4x4 Kernel
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 0.3169 - loss: 1.8483 - val_accuracy: 0.5192 - val_loss: 1.3158
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.5688 - loss: 1.2148 - val_accuracy: 0.6152 - val_loss: 1.0730
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - accuracy: 0.6572 - loss: 0.9607 - val_accuracy: 0.6672 - val_loss: 0.9667
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 19s 47ms/step - accuracy: 0.7308 - loss: 0.7778 - val_accuracy: 0.6727 - val_loss: 0.9561
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - accuracy: 0.7679 - loss: 0.6607 - val_accuracy: 0.6956 - val_loss: 0.9012
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8213 - loss: 0.5120 - val_accuracy: 0.6817 - val_loss: 0.9889
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8597 - loss: 0.4055 - val_accuracy: 0.6888 - val_loss: 1.0195
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8959 - loss: 0.2979 - val_accuracy: 0.6756 - val_loss: 1.1117
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - accuracy: 0.9145 - loss: 0.2431 - val_accuracy: 0.6867 - val_loss: 1.2226
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - accuracy: 0.9474 - loss: 0.1594 - val_accuracy: 0.6961 - val_loss: 1.3855
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6861 - loss: 1.4027
# 16, 32, 64 Filters
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3209 - loss: 1.8346 - val_accuracy: 0.5139 - val_loss: 1.3328
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5446 - loss: 1.2873 - val_accuracy: 0.5875 - val_loss: 1.1616
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6149 - loss: 1.0862 - val_accuracy: 0.6297 - val_loss: 1.0488
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6660 - loss: 0.9561 - val_accuracy: 0.6597 - val_loss: 0.9820
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6939 - loss: 0.8771 - val_accuracy: 0.6656 - val_loss: 0.9651
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7303 - loss: 0.7840 - val_accuracy: 0.6831 - val_loss: 0.9359
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7513 - loss: 0.7153 - val_accuracy: 0.6744 - val_loss: 0.9390
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7681 - loss: 0.6659 - val_accuracy: 0.6963 - val_loss: 0.9258
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7891 - loss: 0.5966 - val_accuracy: 0.6886 - val_loss: 0.9201
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8086 - loss: 0.5548 - val_accuracy: 0.7067 - val_loss: 0.9217
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7001 - loss: 0.9374
# 32, 64, 128 Filters
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.3569 - loss: 1.7673 - val_accuracy: 0.5519 - val_loss: 1.2831
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.5797 - loss: 1.1681 - val_accuracy: 0.6311 - val_loss: 1.0411
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.6697 - loss: 0.9471 - val_accuracy: 0.6753 - val_loss: 0.9514
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7167 - loss: 0.8043 - val_accuracy: 0.6778 - val_loss: 0.9415
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7616 - loss: 0.6733 - val_accuracy: 0.6980 - val_loss: 0.9071
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7989 - loss: 0.5704 - val_accuracy: 0.7206 - val_loss: 0.8607
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.8363 - loss: 0.4662 - val_accuracy: 0.7195 - val_loss: 0.8907
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8737 - loss: 0.3573 - val_accuracy: 0.7119 - val_loss: 0.9651
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9056 - loss: 0.2699 - val_accuracy: 0.7150 - val_loss: 1.0305
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9324 - loss: 0.2036 - val_accuracy: 0.7011 - val_loss: 1.1249
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7019 - loss: 1.1310
# 64, 128, 256 Filters
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 51s 125ms/step - accuracy: 0.3265 - loss: 1.8202 - val_accuracy: 0.5467 - val_loss: 1.2756
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 125ms/step - accuracy: 0.5931 - loss: 1.1484 - val_accuracy: 0.6219 - val_loss: 1.0556
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 124ms/step - accuracy: 0.6866 - loss: 0.8922 - val_accuracy: 0.6791 - val_loss: 0.9463
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 124ms/step - accuracy: 0.7497 - loss: 0.7049 - val_accuracy: 0.7042 - val_loss: 0.8593
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 124ms/step - accuracy: 0.7998 - loss: 0.5694 - val_accuracy: 0.7219 - val_loss: 0.8470
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 126ms/step - accuracy: 0.8567 - loss: 0.4190 - val_accuracy: 0.7192 - val_loss: 0.8780
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 125ms/step - accuracy: 0.8973 - loss: 0.2991 - val_accuracy: 0.7322 - val_loss: 0.9159
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 51s 126ms/step - accuracy: 0.9368 - loss: 0.1871 - val_accuracy: 0.7053 - val_loss: 1.1537
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 125ms/step - accuracy: 0.9531 - loss: 0.1399 - val_accuracy: 0.7234 - val_loss: 1.1924
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 125ms/step - accuracy: 0.9681 - loss: 0.0974 - val_accuracy: 0.7250 - val_loss: 1.2686
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7159 - loss: 1.3193
# Max Pooling
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - accuracy: 0.3602 - loss: 1.7391 - val_accuracy: 0.5722 - val_loss: 1.2194
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.5901 - loss: 1.1493 - val_accuracy: 0.6216 - val_loss: 1.0971
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.6739 - loss: 0.9317 - val_accuracy: 0.6536 - val_loss: 0.9800
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7312 - loss: 0.7716 - val_accuracy: 0.6883 - val_loss: 0.8854
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7773 - loss: 0.6342 - val_accuracy: 0.6970 - val_loss: 0.9026
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.8233 - loss: 0.5185 - val_accuracy: 0.7016 - val_loss: 0.9063
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.8627 - loss: 0.4056 - val_accuracy: 0.7116 - val_loss: 0.8988
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.8880 - loss: 0.3266 - val_accuracy: 0.7163 - val_loss: 0.9843
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9199 - loss: 0.2336 - val_accuracy: 0.7166 - val_loss: 1.1233
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9459 - loss: 0.1625 - val_accuracy: 0.7095 - val_loss: 1.1746
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6988 - loss: 1.2229
# Average Pooling
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - accuracy: 0.3080 - loss: 1.8717 - val_accuracy: 0.5027 - val_loss: 1.3687
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.5214 - loss: 1.3256 - val_accuracy: 0.5669 - val_loss: 1.2144
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.6041 - loss: 1.1215 - val_accuracy: 0.6305 - val_loss: 1.0425
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.6457 - loss: 0.9872 - val_accuracy: 0.6528 - val_loss: 0.9965
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.6807 - loss: 0.9004 - val_accuracy: 0.6420 - val_loss: 1.0228
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7188 - loss: 0.8054 - val_accuracy: 0.6722 - val_loss: 0.9427
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7508 - loss: 0.7093 - val_accuracy: 0.6903 - val_loss: 0.8906
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7752 - loss: 0.6321 - val_accuracy: 0.7005 - val_loss: 0.8833
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7970 - loss: 0.5790 - val_accuracy: 0.7063 - val_loss: 0.8732
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.8244 - loss: 0.5046 - val_accuracy: 0.6964 - val_loss: 0.9417
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6942 - loss: 0.9504
